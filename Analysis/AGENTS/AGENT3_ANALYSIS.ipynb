# %%
import pandas as pd

# %%
df=pd.read_csv("Downloads/Agent3Data.csv")
df
# Out:
#     AGENT  ITERATION  NO OF GHOSTS  RESULT      TIME
# 0      A3          1             1    True  0.302817
# 1      A3          2             1    True  0.131195
# 2      A3          3             1    True  0.179433
# 3      A3          4             1    True  0.124073
# 4      A3          5             1    True  0.147860
# ..    ...        ...           ...     ...       ...
# 981    A3        982            34   False  0.226518
# 982    A3        983            34    True  0.253834
# 983    A3        984            34   False  0.003899
# 984    A3        985            34   False  0.042324
# 985    A3        986            34   False  0.056819
#
# [986 rows x 5 columns]

# %%
Agent = df['AGENT'].iat[0]
Agent
# Out:
# 'A3'

# %%
DF=df["NO OF GHOSTS"].value_counts().to_frame().sort_index()
DF = DF.rename({'NO OF GHOSTS':'COUNT'}, axis=1)
DF.reset_index(inplace=True)
DF = DF.rename(columns = {'index':'NO OF GHOSTS'})
DF
# Out:
#     NO OF GHOSTS  COUNT
# 0              1     29
# 1              2     29
# 2              3     29
# 3              4     29
# 4              5     29
# 5              6     29
# 6              7     29
# 7              8     29
# 8              9     29
# 9             10     29
# 10            11     29
# 11            12     29
# 12            13     29
# 13            14     29
# 14            15     29
# 15            16     29
# 16            17     29
# 17            18     29
# 18            19     29
# 19            20     29
# 20            21     29
# 21            22     29
# 22            23     29
# 23            24     29
# 24            25     29
# 25            26     29
# 26            27     29
# 27            28     29
# 28            29     29
# 29            30     29
# 30            31     29
# 31            32     29
# 32            33     29
# 33            34     29

# %%
DF.columns
# Out:
# Index(['NO OF GHOSTS', 'COUNT'], dtype='object')

# %%
DF1 = pd.merge(df,DF,on ='NO OF GHOSTS',how ='left')
DF1
# Out:
#     AGENT  ITERATION  NO OF GHOSTS  RESULT      TIME  COUNT
# 0      A3          1             1    True  0.302817     29
# 1      A3          2             1    True  0.131195     29
# 2      A3          3             1    True  0.179433     29
# 3      A3          4             1    True  0.124073     29
# 4      A3          5             1    True  0.147860     29
# ..    ...        ...           ...     ...       ...    ...
# 981    A3        982            34   False  0.226518     29
# 982    A3        983            34    True  0.253834     29
# 983    A3        984            34   False  0.003899     29
# 984    A3        985            34   False  0.042324     29
# 985    A3        986            34   False  0.056819     29
#
# [986 rows x 6 columns]

# %%
NOFT= df.groupby(["NO OF GHOSTS", "RESULT"]).size().to_frame()
NOFT
# Out:
#                       0
# NO OF GHOSTS RESULT
# 1            True    29
# 2            False    2
#              True    27
# 3            False    6
#              True    23
# ...                  ..
# 32           True     7
# 33           False   23
#              True     6
# 34           False   24
#              True     5
#
# [67 rows x 1 columns]

# %%
NOFT.reset_index(inplace=True)
NOFT = NOFT.rename({0:'SUCCESSCOUNT'}, axis=1)
NOFT
# Out:
#     NO OF GHOSTS  RESULT  SUCCESSCOUNT
# 0              1    True            29
# 1              2   False             2
# 2              2    True            27
# 3              3   False             6
# 4              3    True            23
# ..           ...     ...           ...
# 62            32    True             7
# 63            33   False            23
# 64            33    True             6
# 65            34   False            24
# 66            34    True             5
#
# [67 rows x 3 columns]

# %%
FinalDf=pd.merge(NOFT, 
                      DF, 
                      on =['NO OF GHOSTS'], 
                      how ='left')
FinalDf
# Out:
#     NO OF GHOSTS  RESULT  SUCCESSCOUNT  COUNT
# 0              1    True            29     29
# 1              2   False             2     29
# 2              2    True            27     29
# 3              3   False             6     29
# 4              3    True            23     29
# ..           ...     ...           ...    ...
# 62            32    True             7     29
# 63            33   False            23     29
# 64            33    True             6     29
# 65            34   False            24     29
# 66            34    True             5     29
#
# [67 rows x 4 columns]

# %%
FinalDf["Survivability"]=FinalDf["SUCCESSCOUNT"]/FinalDf["COUNT"]
FinalDf
# Out:
#     NO OF GHOSTS  RESULT  SUCCESSCOUNT  COUNT  Survivability
# 0              1    True            29     29       1.000000
# 1              2   False             2     29       0.068966
# 2              2    True            27     29       0.931034
# 3              3   False             6     29       0.206897
# 4              3    True            23     29       0.793103
# ..           ...     ...           ...    ...            ...
# 62            32    True             7     29       0.241379
# 63            33   False            23     29       0.793103
# 64            33    True             6     29       0.206897
# 65            34   False            24     29       0.827586
# 66            34    True             5     29       0.172414
#
# [67 rows x 5 columns]

# %%
FinalDf=FinalDf.query('RESULT != False')
FinalDf
# Out:
#     NO OF GHOSTS  RESULT  SUCCESSCOUNT  COUNT  Survivability
# 0              1    True            29     29       1.000000
# 2              2    True            27     29       0.931034
# 4              3    True            23     29       0.793103
# 6              4    True            20     29       0.689655
# 8              5    True            25     29       0.862069
# 10             6    True            22     29       0.758621
# 12             7    True            22     29       0.758621
# 14             8    True            22     29       0.758621
# 16             9    True            22     29       0.758621
# 18            10    True            15     29       0.517241
# 20            11    True            19     29       0.655172
# 22            12    True            16     29       0.551724
# 24            13    True            11     29       0.379310
# 26            14    True            13     29       0.448276
# 28            15    True             9     29       0.310345
# 30            16    True             8     29       0.275862
# 32            17    True             9     29       0.310345
# 34            18    True            17     29       0.586207
# 36            19    True             7     29       0.241379
# 38            20    True            11     29       0.379310
# 40            21    True            11     29       0.379310
# 42            22    True             9     29       0.310345
# 44            23    True            10     29       0.344828
# 46            24    True             8     29       0.275862
# 48            25    True            10     29       0.344828
# 50            26    True            11     29       0.379310
# 52            27    True            11     29       0.379310
# 54            28    True             4     29       0.137931
# 56            29    True            10     29       0.344828
# 58            30    True             9     29       0.310345
# 60            31    True             5     29       0.172414
# 62            32    True             7     29       0.241379
# 64            33    True             6     29       0.206897
# 66            34    True             5     29       0.172414

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x="NO OF GHOSTS", y="Survivability", data=FinalDf).set(title=Agent+" Survivability Test")
fig1 = plt.gcf()
plt.show()

# %%
fig1.savefig("C:/Users/Acer/OneDrive/Desktop/AGENTS/A3Survivability.png",dpi=100)

# %%
Timedf=df.groupby(["NO OF GHOSTS","RESULT"], as_index=False)['TIME'].mean()
Timedf=Timedf.query('RESULT != False')
Timedf
# Out:
#     NO OF GHOSTS  RESULT      TIME
# 0              1    True  0.182048
# 2              2    True  0.183312
# 4              3    True  0.170674
# 6              4    True  0.212555
# 8              5    True  0.188287
# 10             6    True  0.206440
# 12             7    True  0.192681
# 14             8    True  0.204182
# 16             9    True  0.198626
# 18            10    True  0.182150
# 20            11    True  0.186448
# 22            12    True  0.184425
# 24            13    True  0.224537
# 26            14    True  0.196753
# 28            15    True  0.188191
# 30            16    True  0.180240
# 32            17    True  0.229108
# 34            18    True  0.204119
# 36            19    True  0.222203
# 38            20    True  0.210860
# 40            21    True  0.224496
# 42            22    True  0.202107
# 44            23    True  0.216789
# 46            24    True  0.216635
# 48            25    True  0.270244
# 50            26    True  0.192540
# 52            27    True  0.205025
# 54            28    True  0.224844
# 56            29    True  0.218804
# 58            30    True  0.224473
# 60            31    True  0.215716
# 62            32    True  0.196886
# 64            33    True  0.221759
# 66            34    True  0.222138

# %%
graphtime=sns.scatterplot(x="NO OF GHOSTS", y="TIME", data=Timedf).set(title=Agent+" Time Analysis")
fig2 = plt.gcf()
plt.show()

# %%
fig2.savefig("C:/Users/Acer/OneDrive/Desktop/AGENTS/A3TimeAnalysis.png",dpi=100)
